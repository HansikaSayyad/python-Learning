# %% [markdown]
# operators

# %%
#Arthematic operators(+,-,*,/,%,//,**)
#Comaprision/relational operators(>,<,>=,<=,==,!=)
#assisgnment operators(+=,-=,*=,/=,//=,**=)
#bitwise operators(<<,>>,~,&,|)
#logical operators(and,or ,not)
#identity operators(is,is not)
#membership operators(in,not in)

# %%
#Arthematic operators(+,-,*,/,%,//,**)

# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)#quotient
print(a%b)#reminder
print(a//b)#celling value 4(upper value) ,lower value is 3 taking floor value- smaller value (smaller value is -4 than -3)
print(a**b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 3
# 1000

# %% [markdown]
# Bitwise operators(<<,>>,~,&,|)

# %%
#Bitwise operators works on binary number
#Bitwise operators are faster than arthmatics operators
#Bitwise operators perform many operation in easy due to binary number system.

# %%
a=10
b=3
c=2
print(a&b)
print(a|b)
print(a^b)
print(
print(a|b|c)
print(a^b^c)
# Out:
# 2
# 11
# 9
# 11
# 11

# %%
left shift(<<),right shift(>>)
#Def(lef shift):Insert new bits(0) to the LSB
#def(right shift):Delete the bits from the LSB

# %%
a=10
print(a<<1)#a*2powerk
# Out:
# 20

# %%
a=10
print(a<<2)#left shift by 2
print(a<<3)
print(a<<6)
# Out:
# 40
# 80
# 640

# %%
#right shift a≫k=floor(a÷2powerk)
a=10
print(a>>2)
# Out:
# 2
# 0
# 1

# %%
a=10
print(a>>4)
# Out:
# 0

# %%
a=10
print(a >> 3)
# Out:
# 1

# %%
#Bitwise 
a=500
print(~a)
# Out:
# -501

# %%
#def: flip the bits
#Negative number
a=-12#one is less
print(~a)
# Out:
# 11

# %%
a=12 #positive is one is more
print(~a)
# Out:
# -13

# %% [markdown]
# 3.Assignemnt operaters (+=,-=,*=,/=,//=,**=)

# %% [markdown]
# a=10
# a+=5 #a=a+5
# a-=5 #a=a-5

# %%
a=10 
a+=5 #a=a+5
print(a)
a-=5 #a=a-5
print(a)
a*=5 #a=a*5
print(a)
a/=5 #a=a/5
print(a)
a%=5 #a=a%5
print(a)
# Out:
# 15
# 10
# 50
# 10.0
# 0.0

# %%
# &=,/=,^=,<<=,>>=,:=(assignment operaters)
a=10
a&=3 #a=a&5
print(a)
a/=5 #a=a/5
print(a)
a = 10

# 2. Bitwise XOR assignment
a ^= 5  # a = a ^ 5
print(a)

# 3. Bitwise left shift assignment
a <<= 5  # a = a << 5
print(a)

# 4. Bitwise right shift assignment
a >>= 5  # a = a >> 5
print(a)
#:=(walrus operater assign the value in the print statement)

#walrus operator will fist assign the value to the variable then pass it to the outer function
print(x:=2)
print(x=2)
print(x)
# Out:
# 2
# 0.4
# 15
# 480
# 15
# 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 24
#      20 #:=(walrus operater assign the value in the print statement)
#      21
#      22 #walrus operator will fist assign the value to the variable then pass it to oue function
#      23 print(x:=2)
# ---> 24 print(x=2)
#      25 print(x)
#      26 print(x:=9)
#
# TypeError: print() got an unexpected keyword argument 'x'
