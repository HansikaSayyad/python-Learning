# %% [markdown]
# #assisgnment operator(+=,-=,/=,*=,%=)

# %%
a=10
a+=5
print(a)
a-=5
print(a)
a*=5
print(a)
a/=5
print(a)
a%=5
print(a)
# Out:
# 15
# 10
# 50
# 10.0
# 0.0

# %%
#&=,/=,^=,>>==,<<=
a=10
a&=3
print(a)
# Out:
# 2

# %%
a=10
a|=3
print(a)
# Out:
# 11

# %%
a=10
a^=3
print(a)
# Out:
# 9

# %%
a=10
a<<=3
print(a)
# Out:
# 80

# %%
a=10
a>>=3
print(a)
# Out:
# 1

# %%
#warlus operator(:=)
#warlus operator will first assign the value to the variable then pass it to outer function
# Out:
# 1

# %%
print(a:=10)
# Out:
# 10

# %%
#comparision operators(==,!=,<,>,<=,>=)
a=10
b=5
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
print(a<b)
print(a>b)
# Out:
# False
# True
# True
# False
# False
# True

# %%
#logical operators and,or,not
a=True
b=False
print(a and b)
print(a or b)
print( not a)
print(not b)
# Out:
# False
# True
# False
# True

# %%
#identity operators
a=[1,2,3]
b=[1,2,3]
c=a
print(a==b)
print(a is c)
print(a is not b)
print(a is b)
# Out:
# True
# True
# True
# False

# %%
#Membership Operators in,not in
fruits=["mamidipandu","batayi","aratipandu","panasapandu"]
print('batayi' in fruits)
print('batayi' not in fruits)
# Out:
# True
# False

# %%
# interview questions from the operators

# %%
# what is the purpose below code
a=10
b=20
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# 20 10

# %%
p1=100
p2=108
p3=100
print(p1^p2^p3)
# Out:
# 108

# %%
a=10
if (a&1):
    print("hello how are you")
else:
    print("go to hell")
# Out:
# go to hell
