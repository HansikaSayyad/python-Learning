# %% [raw]
# Q-1: python is  "pure" oop labgauge or not?
# no it is not,not "pure",u can write the code using functions alone also and with classes and objects

# %%
print("Hello World")
# Out:
# Hello World

# %% [raw]
# Q-2: Is Python case-sensitive or not?
# ans: YES
#
# Q-3:Is Python a compiler or an interpreter?
# ANS: Both
#
# # How will the code be processed in Python?
# source code->compiler->byte code->pvm(interpreter)->machine code  (BOTH)
# Q-4: Python is platform independent or not? Why?
# Ans: YES, due to "PVM", it becomes platform independent; for every OS, a separate PVM will be there, but the byte code can be run in any PVM
#
# Q-5:In which language is Python developed?
# ANS: CPython is developed in the c language
#     JPython: "  "    "   " JAVA "
#     PyPy: developed and  can be developed in Python
#     Micropython:used in IOT
# Q-6:what is fastest and slowest programming langauge?
#    c,python respectively

# %% [markdown]
# Variable in Python:

# %%
a = 10
b = 20.5
c = "hiiii"
d = True
e = None
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
#---->no char datatype in python

# %% [markdown]
# Rules to define a variable name in python

# %%
#1.Do not start the variable name by an digit,3.special characters(anywhere not only in teh starting),4.hyphen,no spaces in between
#5.can start with  either _(underscore) or character

# %% [markdown]
# delete the variable in python

# %%
var=10

# %%
del var

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(var)
#
# NameError: name 'var' is not defined

# %%
#Q: Swap two strings, number without a temp variable?
a = "hello"
b = 200

a,b=b,a
print(a)
print(b)
print(a,b)
# Out:
# 200
# hello
# 200 hello

# %% [markdown]
# HW:how to swap the two numbers using XOR operator?
